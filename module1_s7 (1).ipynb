# %%
# !pip install mp_api
# Out:
# ...
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.0 MB ? eta -:--:--
#     --------------------------------------- 0.8/44.0 MB 767.9 kB/s eta 0:00:57
#     --------------------------------------- 0.8/44.0 MB 767.9 kB/s eta 0:00:57
#    - -------------------------------------- 1.3/44.0 MB 879.5 kB/s eta 0:00:49
#    - -------------------------------------- 1.6/44.0 MB 936.8 kB/s eta 0:00:46
#    - -------------------------------------- 1.8/44.0 MB 1.0 MB/s eta 0:00:41
#    - -------------------------------------- 2.1/44.0 MB 1.1 MB/s eta 0:00:39
#    -- ------------------------------------- 2.6/44.0 MB 1.2 MB/s eta 0:00:36
#    -- ------------------------------------- 2.9/44.0 MB 1.2 MB/s eta 0:00:34
# ...

# %%
import os
from dotenv import load_dotenv
from mp_api.client import MPRester

# %%
# Load environment variables from the .env file
load_dotenv()
api_key = os.getenv("miP4lnAaROQcFbjLgpZGqM4y6O4NDX4q")

# %%
# Authenticate and run a test query for Silicon (mp-149)
try:
    with MPRester(api_key) as mpr:
        # Fetch basic properties for Silicon
        data = mpr.materials.search(material_ids=["mp-149"])
        
        # Extract and verify the result
        silicon_entry = data[0]
        print("✅ Authentication Successful!")
        print(f"Material ID: {silicon_entry.material_id}")
        print(f"Formula: {silicon_entry.formula_pretty}")
        print(f"Band Gap: {silicon_entry.band_gap:.2f} eV")except Exception as e:
    print("❌ Authentication or Query Failed. Check your API key and network connection.")
    print(f"Error details: {e}")
# Out:
#   Cell In[7], line 12
#     print(f"Band Gap: {silicon_entry.band_gap:.2f} eV")except Exception as e:
#                                                        ^
# SyntaxError: invalid syntax

# %%
from mp_api.client import MPRester



# Authenticate and run a test query for Silicon (mp-149)
try:
    with MPRester(api_key) as mpr:

        # Fetch basic properties for Silicon
        data = mpr.materials.summary.search(
            material_ids=["mp-149"]
        )

        # Extract and verify the result
        silicon_entry = data[0]

        print("✅ Authentication Successful!")
        print(f"Material ID: {silicon_entry.material_id}")
        print(f"Formula: {silicon_entry.formula_pretty}")
        print(f"Band Gap: {silicon_entry.band_gap:.2f} eV")

except Exception as e:
    print("❌ Authentication or Query Failed.")
    print("Check your API key and network connection.")
    print(f"Error details: {e}")
# Out:
# C:\Users\adity\anaconda3\Lib\site-packages\mp_api\client\_server_utils.py:113: MPRestWarning: No API key found, please set explicitly or in the `MP_API_KEY` environment variable.
#   return validate_api_key(api_key=api_key)
# C:\Users\adity\anaconda3\Lib\site-packages\mp_api\client\_server_utils.py:113: MPRestWarning: No API key found, please set explicitly or in the `MP_API_KEY` environment variable.
#   return validate_api_key(api_key=api_key)
# ❌ Authentication or Query Failed.
# Check your API key and network connection.
# Error details: REST query returned with error status code 401 on URL https://api.materialsproject.org/materials/summary/?material_ids=mp-149&_all_fields=True&_limit=1000 with message:
# Response {
#   "message":"No API key found in request"
# }

# %%
from mp_api.client import MPRester

# Your Materials Project API key
api_key = "miP4lnAaROQcFbjLgpZGqM4y6O4NDX4q"

# Authenticate and run a test query for Silicon (mp-149)
try:
    with MPRester(api_key) as mpr:

        # Fetch basic properties for Silicon
        data = mpr.materials.summary.search(
            material_ids=["mp-149"]
        )

        # Extract and verify the result
        silicon_entry = data[0]

        print("✅ Authentication Successful!")
        print(f"Material ID: {silicon_entry.material_id}")
        print(f"Formula: {silicon_entry.formula_pretty}")
        print(f"Band Gap: {silicon_entry.band_gap:.2f} eV")

except Exception as e:
    print("❌ Authentication or Query Failed.")
    print("Check your API key and network connection.")
    print(f"Error details: {e}")
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Authentication Successful!
# Material ID: mp-149
# Formula: Si
# Band Gap: 0.61 eV
